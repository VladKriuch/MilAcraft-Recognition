# %%
# Jupyter notebook of training YOLO as a baseline model
# Note: This notebook was running on google colab, there may be some errors with
# dependencies

# %%
 # Start from installing kaggle
 # !pip install -q kaggle

# %%
# Upload kaggle creds
from google.colab import files

files.upload()
print('') # To not pring kaggle creds

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# Download dataset
# !kaggle datasets download -d khlaifiabilel/military-aircraft-recognition-dataset
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading military-aircraft-recognition-dataset.zip to /content
#  99% 1.12G/1.13G [00:05<00:00, 205MB/s]
# 100% 1.13G/1.13G [00:05<00:00, 234MB/s]

# %%
# Paths
ROOT_DIR = "data/"
IMAGE_DIR = ROOT_DIR + "JPEGImages/"
HORIZONTAL_BB = ROOT_DIR + "Annotations/Horizontal Bounding Boxes/"
ORIENTED_BB = ROOT_DIR + "Annotations/Oriented Bounding Boxes/"

TRAIN_SET_TXT = ROOT_DIR + "ImageSets/Main/train.txt"
TEST_SET_TXT = ROOT_DIR + "ImageSets/Main/test.txt"

# %%
# Imports
import random
import os
import xml.etree.ElementTree as ET
import shutil
import yaml

import cv2
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
# Set seed
random.seed(1991)

# %%
# Reading xml files
# XML reader
def parse_xml(xml_file_path: str):
    # Parses xml file, returns dict
    tree = ET.parse(xml_file_path)

    filename = tree.find('filename').text
    img_size = {
        'width': int(tree.find('size').find('width').text),
        'height': int(tree.find('size').find('height').text),
        'depth': int(tree.find('size').find('depth').text)
    }
    segmented = int(tree.find('segmented').text)
    bboxes = []
    for obj in tree.findall('object'):
        bndbox = obj.find('bndbox')
        bboxes.append({
            'name': obj.find('name').text,
            'xmin': int(bndbox.find('xmin').text),
            'ymin': int(bndbox.find('ymin').text),
            'xmax': int(bndbox.find('xmax').text),
            'ymax': int(bndbox.find('ymax').text)
        })
    database = tree.find('source').find('database').text

    return {
        'filename': filename,
        'img_size': img_size,
        'segmented': segmented,
        'bboxes': bboxes,
        'database': database
    }

def get_xml_file_path(filename, option='HORIZONTAL'):
    if option == 'HORIZONTAL':
        return HORIZONTAL_BB + filename
    elif option == 'ORIENTED':
        return ORIENTED_BB + filename

# %%
# Convert classes to classes_map for YOLO model
classes = ['A19', 'A1', 'A20', 'A16', 'A5', 'A13', 'A15', 'A3', 'A17', 'A11',
       'A14', 'A8', 'A2', 'A10', 'A9', 'A4', 'A18', 'A7', 'A12', 'A6']

classes_map = {item: index for index, item in enumerate(classes)}
classes_map
# Out:
# {'A19': 0,
#  'A1': 1,
#  'A20': 2,
#  'A16': 3,
#  'A5': 4,
#  'A13': 5,
#  'A15': 6,
#  'A3': 7,
#  'A17': 8,
#  'A11': 9,
#  'A14': 10,
#  'A8': 11,
#  'A2': 12,
#  'A10': 13,
#  'A9': 14,
#  'A4': 15,
#  'A18': 16,
#  'A7': 17,
#  'A12': 18,
#  'A6': 19}

# %%
# Get train and test ids
def get_train_set_ids():
    with open(TRAIN_SET_TXT, 'r') as file:
        ids = file.read().splitlines()
    return ids

def get_test_set_ids():
    with open(TEST_SET_TXT, 'r') as file:
        ids = file.read().splitlines()
    return ids

train_set_ids = get_train_set_ids()
test_set_ids = get_test_set_ids()
print(f'Size of train set is: {len(train_set_ids)}')
print(f'Size of test set is: {len(test_set_ids)}')
print(f'Total images: {len(train_set_ids) + len(test_set_ids)}')
# Out:
# Size of train set is: 1331
# Size of test set is: 2511
# Total images: 3842

# %%
# Helping functions
# Displaying images

def get_image(image_path: str):
    img = cv2.imread(image_path)
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


def get_image_shape(image_path: str):
    img = cv2.imread(image_path)
    return img.shape

def get_image_from_id(obj_id: str):
    image_path = IMAGE_DIR + obj_id + ".jpg"
    return get_image(image_path)

def display_image(image_name: str):
    image_path = IMAGE_DIR + image_name
    plt.imshow(get_image(image_path))

def get_random_img_names():
    return random.sample(os.listdir(IMAGE_DIR), 16)

# %%
# Convert the info dict to the required yolo format and write it to disk
def convert_to_yolov5(info_dict, obj_id, save_folder):
    print_buffer = []

    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = classes_map[b["name"]]
        except KeyError:
            print("Invalid Class. Must be one from ", classes_map.keys())

        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width    = (b["xmax"] - b["xmin"])
        b_height   = (b["ymax"] - b["ymin"])

        # Normalise the co-ordinates by the dimensions of the image
        image_h, image_w, image_c = get_image_shape(IMAGE_DIR + obj_id + ".jpg")
        b_center_x /= image_w
        b_center_y /= image_h
        b_width    /= image_w
        b_height   /= image_h

        #Write the bbox details to the file
        print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))

    # Name of the file which we have to save
    save_file_name = os.path.join(save_folder, obj_id + ".txt")

    # Save the annotation to disk
    # print("\n".join(print_buffer), file= open(save_file_name, "w"))
    with open(save_file_name, 'w') as fl:
      fl.write("\n".join(print_buffer))

# %%
# Create appropriate folders
# !mkdir "data for yolo"
# !mkdir "data for yolo/labels"
# !mkdir "data for yolo/images"
# !mkdir "data for yolo/labels/train"
# !mkdir "data for yolo/labels/test"
# !mkdir "data for yolo/images/train"
# !mkdir "data for yolo/images/test"

# %%
# Convert dataset to yolo format
for obj_id in train_set_ids:
  info_dict = parse_xml(HORIZONTAL_BB + str(obj_id) + ".xml")
  convert_to_yolov5(info_dict, str(obj_id), "data for yolo/labels/train/")

for obj_id in test_set_ids:
  info_dict = parse_xml(HORIZONTAL_BB + str(obj_id) + ".xml")
  convert_to_yolov5(info_dict, str(obj_id), "data for yolo/labels/test/")

# %%
# Copy images to YOLO
def move_files_to_folder(list_of_files, destination_folder):
    for f in list_of_files:
        try:
            shutil.move(f, destination_folder)
        except:
            print(f)
            assert False

train_img_files = [IMAGE_DIR + str(obj_id) + ".jpg" for obj_id in train_set_ids]
test_img_files = [IMAGE_DIR + str(obj_id) + ".jpg" for obj_id in test_set_ids]

# Move the splits into their folders
move_files_to_folder(train_img_files, 'data for yolo/images/train')
move_files_to_folder(test_img_files, 'data for yolo/images/test')

# %%
class_id_to_name_mapping = dict(zip(classes_map.values(), classes_map.keys()))

# %%
# Make .yaml file for yolo
d = {
    'path':'../data for yolo/',
    'train': 'images/train',
    'val': 'images/test',
    'nc': 20,
    'names': class_id_to_name_mapping
    }

with open('dataset.yml', 'w') as yaml_file:
    yaml.dump(d, yaml_file, default_flow_style=False)

# %%
# Define our hyp yaml file
hyps = {
     "lr0": 0.01,  # initial learning rate (SGD=1E-2, Adam=1E-3)
 'lrf': 0.01,  # final OneCycleLR learning rate (lr0 * lrf)
 "momentum": 0.937,  # SGD momentum/Adam beta1
 "weight_decay": 0.0005,  # optimizer weight decay 5e-4
 "warmup_epochs": 3.0,  # warmup epochs (fractions ok)
 "warmup_momentum": 0.8,  # warmup initial momentum
 "warmup_bias_lr": 0.1,  # warmup initial bias lr
 "box": 0.05,  # box loss gain
 "cls": 0.5,  # cls loss gain
 "cls_pw": 1.0,  # cls BCELoss positive_weight
 "obj": 1.0,  # obj loss gain (scale with pixels)
 "obj_pw": 1.0,  # obj BCELoss positive_weight
 "iou_t": 0.20,  # IoU training threshold
 "anchor_t": 4.0,  # anchor-multiple threshold
 # anchors: 3  # anchors per output layer (0 to ignore)
 "fl_gamma": 0.0,  # focal loss gamma (efficientDet default gamma=1.5)
 "hsv_h": 0.015,  # image HSV-Hue augmentation (fraction)
 "hsv_s": 0.5,  # image HSV-Saturation augmentation (fraction)
 "hsv_v": 0.4,  # image HSV-Value augmentation (fraction)
 "degrees": 0.0,  # image rotation (+/- deg)
 "translate": 0.1,  # image translation (+/- fraction)
 "scale": 0.4,  # image scale (+/- gain)
 "shear": 0.00, # image shear (+/- deg)
 "perspective": 0.0,  # image perspective (+/- fraction), range 0-0.001
 "flipud": 0.0,  # image flip up-down (probability)
 "fliplr": 0.0,  # image flip left-right (probability)
 "mosaic": 1.0,  # image mosaic (probability)
 "mixup": 0.0,  # image mixup (probability)
 "copy_paste": 0.0  # segment copy-paste (probability)
}

with open('hyps.yml', 'w') as yaml_file:
    yaml.dump(hyps, yaml_file, default_flow_style=False)

# %%
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.198-py3-none-any.whl (641 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.7/641.7 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->ultralytics) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->ultralytics) (17.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.198

# %%
# Clone yolo git repo
# !git clone https://github.com/ultralytics/yolov5  # clone
# !pip install -r yolov5/requirements.txt  # install
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# Collecting gitpython>=3.1.30 (from -r yolov5/requirements.txt (line 5))
#   Downloading GitPython-3.1.37-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 8)) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 9)) (9.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 13)) (1.11.3)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 15)) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 16)) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 17)) (4.66.1)
# Requirement already satisfied: ultralytics>=8.0.147 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 18)) (8.0.198)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 42)) (67.7.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (17.0.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.147->-r yolov5/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2023.3.post1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.37 smmap-5.0.1

# %%
# Train YOLO5 for 75 epochs
# !python yolov5/train.py --img 800 --batch 48 --epochs 115 --data dataset.yml --name 'mar results' --patience 50 --weights yolov5s.pt --hyp hyp.yml
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=hyp.yml, epochs=115, batch_size=48, imgsz=800, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=mar results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-227-ge4df1ec Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: anchor_t=4.0, box=0.05, cls=0.3, cls_pw=1.0, copy_paste=0.0, degrees=0.0, fl_gamma=0.0, fliplr=0.1, flipud=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, iou_t=0.2, lr0=0.01, lrf=0.1, mixup=0.1, momentum=0.937, mosaic=1.0, obj=0.7, obj_pw=1.0, perspective=0.0, scale=0.6, shear=0.0, translate=0.1, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=20
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     67425  models.yolo.Detect                      [20, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7073569 parameters, 7073569 gradients, 16.1 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.000375), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8)), Rotate(p=0.7, limit=(-90, 90), interpolation=1, border_mode=4, value=None, mask_value=None, rotate_method='largest_box', crop_border=False), VerticalFlip(p=0.5), HorizontalFlip(p=0.1)
# train: Scanning /content/data for yolo/labels/train.cache... 1331 images, 0 backgrounds, 0 corrupt: 100% 1331/1331 [00:00<?, ?it/s]
# val: Scanning /content/data for yolo/labels/test.cache... 2511 images, 0 backgrounds, 0 corrupt: 100% 2511/2511 [00:00<?, ?it/s]
#
# AutoAnchor: 5.59 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/mar results7/labels.jpg...
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to yolov5/runs/train/mar results7
# Starting training for 115 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/114      14.3G    0.09233    0.06138    0.03808        330        800: 100% 28/28 [01:46<00:00,  3.82s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/27 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   4% 1/27 [00:07<03:04,  7.08s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   7% 2/27 [00:13<02:49,  6.77s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  11% 3/27 [00:20<02:38,  6.62s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  15% 4/27 [00:26<02:32,  6.63s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  22% 6/27 [00:38<02:12,  6.33s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  26% 7/27 [00:45<02:05,  6.26s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  30% 8/27 [00:51<01:58,  6.25s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  33% 9/27 [00:57<01:51,  6.20s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  37% 10/27 [01:03<01:45,  6.20s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  41% 11/27 [01:09<01:39,  6.20s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  44% 12/27 [01:15<01:32,  6.19s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  52% 14/27 [01:27<01:17,  5.99s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  56% 15/27 [01:33<01:12,  6.06s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  59% 16/27 [01:40<01:07,  6.11s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  63% 17/27 [01:46<01:01,  6.14s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  67% 18/27 [01:52<00:55,  6.16s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  70% 19/27 [01:58<00:49,  6.22s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  74% 20/27 [02:05<00:43,  6.22s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  78% 21/27 [02:11<00:37,  6.25s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  81% 22/27 [02:17<00:31,  6.24s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  85% 23/27 [02:24<00:25,  6.30s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  89% 24/27 [02:30<00:18,  6.28s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  93% 25/27 [02:36<00:12,  6.31s/it]WARNING ⚠️ NMS time limit 5.300s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  96% 26/27 [02:43<00:06,  6.55s/it]WARNING ⚠️ NMS time limit 1.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [02:46<00:00,  6.17s/it]
#                    all       2511      14471      0.018      0.166     0.0142    0.00383
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/114      14.3G    0.06406    0.04965    0.03685        335        800: 100% 28/28 [01:32<00:00,  3.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:17<00:00,  2.87s/it]
#                    all       2511      14471     0.0228       0.72     0.0276     0.0091
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/114      14.3G    0.05882    0.04418    0.03618        334        800: 100% 28/28 [01:31<00:00,  3.27s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:10<00:00,  2.62s/it]
#                    all       2511      14471     0.0154      0.706     0.0212    0.00728
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/114      14.3G    0.05239    0.04195    0.03547        367        800: 100% 28/28 [01:33<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:03<00:00,  2.36s/it]
#                    all       2511      14471     0.0313      0.664       0.04     0.0161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/114      14.3G    0.04565    0.04028     0.0361        273        800: 100% 28/28 [01:35<00:00,  3.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.24s/it]
#                    all       2511      14471     0.0412      0.616     0.0446     0.0183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/114      14.3G    0.04026    0.04018    0.03512        381        800: 100% 28/28 [01:39<00:00,  3.54s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:02<00:00,  2.33s/it]
#                    all       2511      14471     0.0463      0.865     0.0632     0.0312
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/114      14.3G     0.0382     0.0379    0.03454        327        800: 100% 28/28 [01:38<00:00,  3.51s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:02<00:00,  2.32s/it]
#                    all       2511      14471     0.0439      0.925     0.0662      0.036
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/114      14.3G    0.03799    0.03636      0.035        257        800: 100% 28/28 [01:36<00:00,  3.44s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:03<00:00,  2.33s/it]
#                    all       2511      14471     0.0476      0.932     0.0715     0.0421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/114      14.3G    0.03576    0.03648    0.03487        344        800: 100% 28/28 [01:38<00:00,  3.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:01<00:00,  2.27s/it]
#                    all       2511      14471     0.0462      0.959     0.0777     0.0431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/114      14.3G    0.03505    0.03628    0.03478        424        800: 100% 28/28 [01:36<00:00,  3.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:02<00:00,  2.31s/it]
#                    all       2511      14471     0.0404      0.963     0.0752     0.0451
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/114      14.3G    0.03454    0.03527    0.03484        343        800: 100% 28/28 [01:37<00:00,  3.48s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.26s/it]
#                    all       2511      14471     0.0474      0.941     0.0864     0.0497
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/114      14.3G    0.03238     0.0349    0.03495        364        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:02<00:00,  2.33s/it]
#                    all       2511      14471     0.0491      0.941     0.0884     0.0538
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/114      14.3G    0.03368    0.03525    0.03416        338        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:02<00:00,  2.32s/it]
#                    all       2511      14471     0.0565      0.791     0.0993     0.0598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/114      14.3G    0.03141    0.03512    0.03358        283        800: 100% 28/28 [01:38<00:00,  3.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471     0.0638      0.715      0.112     0.0671
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/114      14.3G    0.03245    0.03367    0.03451        421        800: 100% 28/28 [01:40<00:00,  3.59s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.17s/it]
#                    all       2511      14471      0.079       0.53      0.117     0.0662
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/114      14.3G    0.03216    0.03348    0.03313        362        800: 100% 28/28 [01:38<00:00,  3.52s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:01<00:00,  2.29s/it]
#                    all       2511      14471      0.128      0.341      0.138     0.0865
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/114      14.3G    0.03133    0.03353    0.03326        330        800: 100% 28/28 [01:36<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:01<00:00,  2.27s/it]
#                    all       2511      14471      0.159      0.315       0.15      0.092
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/114      14.3G    0.03161    0.03335    0.03255        350        800: 100% 28/28 [01:36<00:00,  3.44s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:02<00:00,  2.30s/it]
#                    all       2511      14471      0.231      0.335      0.168      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/114      14.3G    0.03116    0.03262    0.03233        333        800: 100% 28/28 [01:36<00:00,  3.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.264      0.304      0.171      0.105
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/114      14.3G    0.03091    0.03266    0.03244        370        800: 100% 28/28 [01:36<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.22s/it]
#                    all       2511      14471      0.232      0.337      0.195      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/114      14.3G     0.0312    0.03277    0.03146        361        800: 100% 28/28 [01:37<00:00,  3.48s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.268      0.367      0.196       0.12
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/114      14.3G    0.03121     0.0332    0.03095        359        800: 100% 28/28 [01:37<00:00,  3.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:01<00:00,  2.27s/it]
#                    all       2511      14471       0.22      0.372      0.215      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/114      14.3G    0.03054    0.03311    0.03034        378        800: 100% 28/28 [01:36<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:01<00:00,  2.29s/it]
#                    all       2511      14471      0.261       0.36      0.234       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/114      14.3G    0.03081    0.03353    0.03012        340        800: 100% 28/28 [01:38<00:00,  3.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.278       0.37      0.254      0.157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/114      14.3G    0.03133    0.03431    0.02937        399        800: 100% 28/28 [01:41<00:00,  3.62s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.305      0.362      0.251      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/114      14.3G    0.03009    0.03204    0.02876        372        800: 100% 28/28 [01:38<00:00,  3.51s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.238      0.372      0.296      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/114      14.3G    0.02984    0.03328    0.02852        384        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:01<00:00,  2.29s/it]
#                    all       2511      14471      0.258      0.338      0.267       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/114      14.3G    0.02957    0.03077    0.02725        302        800: 100% 28/28 [01:33<00:00,  3.35s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.26s/it]
#                    all       2511      14471      0.269       0.39      0.301      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/114      14.3G    0.02991    0.03268    0.02727        345        800: 100% 28/28 [01:37<00:00,  3.48s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.24s/it]
#                    all       2511      14471       0.25      0.437      0.313      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/114      14.3G    0.03062    0.03216    0.02629        335        800: 100% 28/28 [01:32<00:00,  3.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471       0.25      0.516      0.346      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/114      14.3G    0.03003    0.03126    0.02544        332        800: 100% 28/28 [01:33<00:00,  3.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.272      0.507      0.328      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/114      14.3G    0.02992    0.03115    0.02511        370        800: 100% 28/28 [01:34<00:00,  3.38s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.294      0.514      0.356      0.232
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/114      14.3G    0.03003    0.03204    0.02442        412        800: 100% 28/28 [01:33<00:00,  3.35s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.12s/it]
#                    all       2511      14471      0.283       0.58      0.336      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/114      14.3G    0.03023    0.03136     0.0236        459        800: 100% 28/28 [01:34<00:00,  3.38s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471      0.291      0.592      0.412       0.26
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/114      14.3G     0.0291    0.03088    0.02272        290        800: 100% 28/28 [01:29<00:00,  3.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.14s/it]
#                    all       2511      14471      0.296      0.613      0.421      0.266
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/114      14.3G    0.02984    0.03152    0.02246        346        800: 100% 28/28 [01:33<00:00,  3.34s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.11s/it]
#                    all       2511      14471      0.296      0.611      0.404      0.254
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/114      14.3G    0.02987    0.03127    0.02158        314        800: 100% 28/28 [01:34<00:00,  3.39s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.19s/it]
#                    all       2511      14471      0.286      0.633      0.405      0.246
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/114      14.3G    0.02953    0.03153    0.02137        362        800: 100% 28/28 [01:33<00:00,  3.35s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.322      0.665      0.471      0.319
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/114      14.3G    0.02906    0.03138    0.02088        385        800: 100% 28/28 [01:32<00:00,  3.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.19s/it]
#                    all       2511      14471      0.322       0.62      0.451      0.298
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/114      14.3G    0.02916    0.03161     0.0204        388        800: 100% 28/28 [01:34<00:00,  3.39s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.12s/it]
#                    all       2511      14471      0.327      0.673      0.479      0.311
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/114      14.3G    0.02928    0.03275    0.01964        299        800: 100% 28/28 [01:34<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.24s/it]
#                    all       2511      14471       0.36      0.718      0.503      0.336
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/114      14.3G    0.02931    0.03002    0.01975        361        800: 100% 28/28 [01:31<00:00,  3.29s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.19s/it]
#                    all       2511      14471       0.38      0.695      0.533      0.344
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/114      14.3G    0.02986    0.03179    0.01889        340        800: 100% 28/28 [01:31<00:00,  3.28s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.381      0.684      0.534      0.342
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/114      14.3G    0.02871    0.03083    0.01787        365        800: 100% 28/28 [01:34<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.376      0.684      0.546      0.349
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/114      14.3G    0.02797    0.03092    0.01767        330        800: 100% 28/28 [01:30<00:00,  3.23s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.17s/it]
#                    all       2511      14471      0.431      0.737      0.595      0.404
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/114      14.3G    0.02857    0.03084    0.01727        332        800: 100% 28/28 [01:33<00:00,  3.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.17s/it]
#                    all       2511      14471      0.409      0.717      0.556      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/114      14.3G    0.02872    0.03035    0.01711        356        800: 100% 28/28 [01:35<00:00,  3.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.17s/it]
#                    all       2511      14471      0.396      0.697      0.589      0.392
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/114      14.3G    0.02849    0.03045      0.016        304        800: 100% 28/28 [01:32<00:00,  3.32s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.434      0.725      0.605        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/114      14.3G      0.029     0.0316    0.01637        266        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.463      0.727      0.618      0.405
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/114      14.3G    0.02822    0.03056    0.01623        376        800: 100% 28/28 [01:33<00:00,  3.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471       0.47      0.726      0.606      0.399
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/114      14.3G    0.02909    0.03011    0.01532        341        800: 100% 28/28 [01:36<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.512      0.781      0.646      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/114      14.3G    0.02848    0.03014    0.01493        372        800: 100% 28/28 [01:31<00:00,  3.27s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.14s/it]
#                    all       2511      14471       0.51      0.737       0.65      0.439
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/114      14.3G    0.02765    0.03056    0.01473        278        800: 100% 28/28 [01:31<00:00,  3.27s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.19s/it]
#                    all       2511      14471      0.512      0.758      0.669      0.442
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/114      14.3G    0.02779    0.03108    0.01435        469        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.21s/it]
#                    all       2511      14471      0.519       0.76      0.686      0.461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/114      14.3G    0.02817    0.03004    0.01381        385        800: 100% 28/28 [01:32<00:00,  3.30s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471      0.567      0.789      0.711      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/114      14.3G    0.02823    0.03086     0.0141        343        800: 100% 28/28 [01:31<00:00,  3.28s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.22s/it]
#                    all       2511      14471       0.56      0.782      0.709      0.475
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/114      14.3G    0.02713    0.03008    0.01342        287        800: 100% 28/28 [01:31<00:00,  3.28s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.567      0.782      0.723      0.489
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/114      14.3G    0.02778     0.0303    0.01303        369        800: 100% 28/28 [01:35<00:00,  3.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.17s/it]
#                    all       2511      14471      0.584      0.795      0.742      0.507
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/114      14.3G    0.02731    0.02989    0.01252        432        800: 100% 28/28 [01:33<00:00,  3.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.26s/it]
#                    all       2511      14471      0.618      0.788      0.746      0.505
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/114      14.3G    0.02846    0.03061    0.01313        281        800: 100% 28/28 [01:34<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.631      0.819      0.766      0.518
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/114      14.3G    0.02709    0.02983    0.01227        332        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.22s/it]
#                    all       2511      14471      0.604      0.784      0.734      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/114      14.3G    0.02719    0.03062    0.01165        352        800: 100% 28/28 [01:34<00:00,  3.37s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.14s/it]
#                    all       2511      14471      0.655      0.781       0.75      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/114      14.3G    0.02734    0.03006    0.01134        375        800: 100% 28/28 [01:36<00:00,  3.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.16s/it]
#                    all       2511      14471      0.655      0.811      0.786      0.521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/114      14.3G      0.028    0.02943    0.01158        394        800: 100% 28/28 [01:31<00:00,  3.26s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:56<00:00,  2.10s/it]
#                    all       2511      14471      0.663      0.771      0.771      0.527
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/114      14.3G    0.02761    0.02952    0.01166        289        800: 100% 28/28 [01:32<00:00,  3.30s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.14s/it]
#                    all       2511      14471       0.69      0.787      0.791      0.535
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/114      14.3G    0.02749    0.02986    0.01067        324        800: 100% 28/28 [01:30<00:00,  3.24s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.14s/it]
#                    all       2511      14471       0.71       0.82      0.822      0.566
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/114      14.3G     0.0272    0.03138    0.01069        318        800: 100% 28/28 [01:30<00:00,  3.23s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471      0.718      0.797      0.814      0.576
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/114      14.3G    0.02703    0.02824    0.01009        242        800: 100% 28/28 [01:34<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.13s/it]
#                    all       2511      14471      0.701      0.816      0.814      0.564
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/114      14.3G    0.02681     0.0286   0.009921        377        800: 100% 28/28 [01:34<00:00,  3.38s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.13s/it]
#                    all       2511      14471       0.73      0.813      0.815      0.571
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/114      14.3G    0.02734    0.02988    0.01001        350        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.16s/it]
#                    all       2511      14471      0.705      0.812      0.822      0.565
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/114      14.3G    0.02668     0.0296   0.009789        353        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:56<00:00,  2.10s/it]
#                    all       2511      14471      0.769       0.81      0.845      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/114      14.3G    0.02695    0.02837    0.01013        263        800: 100% 28/28 [01:33<00:00,  3.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471       0.76      0.794      0.838      0.588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/114      14.3G    0.02719    0.02869   0.009554        349        800: 100% 28/28 [01:32<00:00,  3.32s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.761      0.793      0.824       0.57
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/114      14.3G    0.02701    0.02992   0.009279        240        800: 100% 28/28 [01:35<00:00,  3.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.17s/it]
#                    all       2511      14471      0.798      0.828       0.87      0.612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/114      14.3G    0.02659    0.02929   0.008949        312        800: 100% 28/28 [01:28<00:00,  3.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.24s/it]
#                    all       2511      14471      0.786      0.807      0.852      0.592
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/114      14.3G    0.02658    0.02993   0.008797        313        800: 100% 28/28 [01:33<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.13s/it]
#                    all       2511      14471      0.801      0.839      0.872      0.611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/114      14.3G     0.0266    0.02885   0.008407        293        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.16s/it]
#                    all       2511      14471      0.829      0.831      0.883      0.619
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/114      14.3G    0.02586    0.02958   0.008397        351        800: 100% 28/28 [01:31<00:00,  3.26s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:56<00:00,  2.09s/it]
#                    all       2511      14471      0.829      0.835      0.887      0.621
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/114      14.3G    0.02617    0.02807   0.007904        276        800: 100% 28/28 [01:35<00:00,  3.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471      0.808      0.818      0.876      0.618
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/114      14.3G    0.02623    0.02916   0.008275        356        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.12s/it]
#                    all       2511      14471      0.816      0.842      0.888       0.63
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/114      14.3G    0.02604    0.02795   0.007855        353        800: 100% 28/28 [01:29<00:00,  3.21s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.843      0.843      0.901      0.641
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/114      14.3G    0.02585    0.03005   0.007541        319        800: 100% 28/28 [01:35<00:00,  3.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.21s/it]
#                    all       2511      14471      0.839      0.844      0.896      0.639
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/114      14.3G    0.02584    0.03003   0.007504        303        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.21s/it]
#                    all       2511      14471      0.842      0.862      0.906      0.644
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/114      14.3G      0.026    0.02858    0.00711        247        800: 100% 28/28 [01:33<00:00,  3.35s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.855      0.855      0.913      0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/114      14.3G    0.02547    0.02853    0.00705        355        800: 100% 28/28 [01:31<00:00,  3.25s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.846      0.851      0.902      0.643
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/114      14.3G    0.02531    0.02906    0.00711        315        800: 100% 28/28 [01:35<00:00,  3.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.12s/it]
#                    all       2511      14471      0.847       0.86      0.912      0.647
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/114      14.3G    0.02571    0.02843   0.006967        297        800: 100% 28/28 [01:36<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.26s/it]
#                    all       2511      14471      0.845      0.845      0.903      0.646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/114      14.3G    0.02553    0.02775    0.00672        345        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.16s/it]
#                    all       2511      14471      0.826      0.828      0.895       0.65
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/114      14.3G    0.02551    0.02889   0.006742        426        800: 100% 28/28 [01:35<00:00,  3.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471       0.85      0.848      0.907      0.647
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/114      14.3G    0.02537    0.02869   0.006419        349        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:56<00:00,  2.08s/it]
#                    all       2511      14471      0.875      0.853      0.919      0.649
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/114      14.3G    0.02531    0.02883   0.006729        308        800: 100% 28/28 [01:37<00:00,  3.48s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.21s/it]
#                    all       2511      14471       0.84      0.853       0.91      0.652
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/114      14.3G    0.02447    0.02812   0.006371        434        800: 100% 28/28 [01:36<00:00,  3.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.24s/it]
#                    all       2511      14471      0.852      0.839       0.91      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/114      14.3G    0.02465    0.02836   0.006268        265        800: 100% 28/28 [01:35<00:00,  3.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.19s/it]
#                    all       2511      14471       0.86      0.843      0.908      0.655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/114      14.3G    0.02534    0.02712   0.006171        338        800: 100% 28/28 [01:35<00:00,  3.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.23s/it]
#                    all       2511      14471      0.855      0.858      0.914      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/114      14.3G    0.02462    0.02825   0.005854        337        800: 100% 28/28 [01:36<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471      0.851      0.853      0.918      0.655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/114      14.3G    0.02506    0.02934   0.006236        253        800: 100% 28/28 [01:39<00:00,  3.57s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.20s/it]
#                    all       2511      14471      0.877      0.864      0.926      0.668
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/114      14.3G    0.02479    0.02789   0.006118        307        800: 100% 28/28 [01:33<00:00,  3.34s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [01:00<00:00,  2.24s/it]
#                    all       2511      14471      0.877      0.854      0.921      0.666
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/114      14.3G    0.02462     0.0284   0.006273        303        800: 100% 28/28 [01:36<00:00,  3.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.16s/it]
#                    all       2511      14471      0.879      0.864      0.928      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/114      14.3G    0.02433    0.02853   0.005641        208        800: 100% 28/28 [01:36<00:00,  3.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.15s/it]
#                    all       2511      14471      0.867      0.864      0.923      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/114      14.3G    0.02437    0.02814   0.005854        267        800: 100% 28/28 [01:33<00:00,  3.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.12s/it]
#                    all       2511      14471      0.882       0.87      0.928       0.67
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/114      14.3G     0.0241     0.0285   0.005747        329        800: 100% 28/28 [01:37<00:00,  3.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:57<00:00,  2.14s/it]
#                    all       2511      14471      0.878       0.86      0.927      0.671
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/114      14.3G    0.02437     0.0289   0.005786        354        800: 100% 28/28 [01:35<00:00,  3.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:59<00:00,  2.22s/it]
#                    all       2511      14471      0.867      0.857      0.919      0.669
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/114      14.3G    0.02421     0.0279   0.005662        409        800: 100% 28/28 [01:34<00:00,  3.37s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 27/27 [00:58<00:00,  2.18s/it]
#                    all       2511      14471      0.863      0.846      0.913      0.666
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/114      14.3G    0.02422    0.02823   0.005783        472        800:  86% 24/28 [01:22<00:13,  3.41s/it]
